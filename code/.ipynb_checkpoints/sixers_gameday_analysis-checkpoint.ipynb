# %%
import import_ipynb  
import utils         
import pandas as pd

# %%
years = [2021, 2022, 2023, 2024, 2025]
philly_crime_all = utils.load_philly_crime_data(years)

# %%
# 1. Define Stadium Coordinates (Wells Fargo Center)
wells_fargo = (-75.1720, 39.9012)

# 2. Preprocess Crime Data
philly_processed = utils.preprocess_crime_data(
    philly_crime_all,
    stadium_coords=wells_fargo,
    date_col='dispatch_date_time'
)

# 3. Load Sixers Game Dates (2021–2024)
sixers_games_all = utils.load_all_sixers_games()

# Filter to home games only
home_games = sixers_games_all[sixers_games_all["Location"] == "Home"]

# 4. Tag Game Windows
philly_tagged = utils.tag_game_windows(
    df=philly_processed,
    games_df=home_games,
    team_name="76ers"
)

# 5. Compute Δ Crime by Distance Bands
philly_delta_by_distance = utils.compute_distance_crime_delta(philly_tagged, bins=[0, 1000, 5000, 10000])

# 6. Plot Stadium-Centered Radius Map with Δ Crime Bar Chart
utils.plot_stadium_radii_map_with_bar_chart(
    stadium_coords=wells_fargo,
    crime_df=philly_tagged,
    delta_df=philly_delta_by_distance,       # ✅ This is required now
    radii_meters=[1000, 5000, 10000],
    title="Crime Δ by Radius Around Wells Fargo Center",
    zoom=9
)
# Out:
# Initial rows: 655481
# After dropping null distance_to_stadium_m: 655481
# Using bins (meters): [0, 1000, 5000, 10000, inf]
# Distance band distribution:
# distance_band_km
# 0–1km        680
# 1–5km      37777
# 5–10km    143318
# >10km     473706
# Name: count, dtype: int64
# Grouped counts:
#    is_game_window distance_band_km  crime_count
# 0           False            0–1km          602
# 1           False            1–5km        33310
# 2           False           5–10km       126696
# 3           False            >10km       419252
# 4            True            0–1km           78
# 5            True            1–5km         4467
# 6            True           5–10km        16622
# 7            True            >10km        54454
# Pivot table:
# is_game_window     False  True
# distance_band_km
# 0–1km                602     78
# 1–5km              33310   4467
# 5–10km            126696  16622
# >10km             419252  54454
# Number of game days: 186
# Number of non-game days: 1419
# Final delta stats:
#                   non_game_crime  game_crime  avg_game_crime  \
# distance_band_km
# 0–1km                        602          78        0.419355
# 1–5km                      33310        4467       24.016129
# 5–10km                    126696       16622       89.365591
# >10km                     419252       54454      292.763441
#
#                   avg_non_game_crime  delta_crime
# distance_band_km
# 0–1km                       0.424242    -0.004888
# 1–5km                      23.474278     0.541851
# 5–10km                     89.285412     0.080179
# >10km                     295.455955    -2.692514
# <string>:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.

# %% [markdown]
# This shows maybe what we would have expected:
# - There is no signficant increase or decrease in citywide crime on gamedays
# - There is no change in crime around the stadium

# %% [markdown]
# Explanations:
# - Games are less important
# - People care less about the sport and the outcome
# - Lower attendance in the stadium
